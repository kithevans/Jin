# %%
import numpy as np
import os
import tensorflow as tf
import pandas as pd
import random
# to make this notebook's output stable across runs
def reset_graph(seed=42):
    tf.random.set_seed(seed)
    np.random.seed(seed)
    random.seed(seed)
    os.environ['PYTHONHASHSEED']=str(seed)

# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt

reset_graph()

# %%
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = "-1"

# %%
HH = pd.read_csv('HH_daily.csv')
WTI = pd.read_csv('WTI_daily.csv')
gold = pd.read_csv('COMEX_Gold_daily.csv')
copper = pd.read_csv('COMEX_Copper_daily.csv')
nickel = pd.read_csv('Nickel_daily.csv')
zinc = pd.read_csv('Zinc_daily.csv')

# %% [markdown]
# # HH

# %%
HH.dropna(inplace=True)
HH.reset_index(drop=True,inplace=True)

# %%
plt.figure(figsize=(15, 8))
plt.plot(HH["HH_daily"])

# %%
num = 5

lags = range(1, (1+num))
HH = HH.assign(**{
    '{} (t-{})'.format('HH_daily', t): HH["HH_daily"].shift(t)
    for t in lags
})

# %%
for i in range(num):
    HH.drop([i],inplace=True)

HH.reset_index(drop=True,inplace=True)

# %%
HH1 = HH.loc[:int((len(HH)-1)*0.2209241),]
HH2 = HH.loc[int((len(HH)-1)*0.2209241)+1:int((len(HH)-1)*0.2710214),]
HH3 = HH.loc[int((len(HH)-1)*0.2710214)+1:int((len(HH)-1)*0.3218269),]
HH4 = HH.loc[int((len(HH)-1)*0.3218269)+1:int((len(HH)-1)*0.7072048),]
HH5 = HH.loc[int((len(HH)-1)*0.7072048)+1:int((len(HH)-1)*0.7571252),]
HH6 = HH.loc[int((len(HH)-1)*0.7571252)+1:int((len(HH)-1)*0.9355638),]
HH7 = HH.loc[int((len(HH)-1)*0.9355638)+1:len(HH)-251,]

# %%
frames = [HH1,HH2,HH3,HH4,HH5,HH6,HH7]
HH_predict = pd.concat(frames)
HH_forecasting = HH.loc[(len(HH)-250):len(HH),:]

# %%
X_train = HH_predict.drop("HH_daily", axis=1)
X_train = X_train.drop("Date", axis=1)
y_train = HH_predict["HH_daily"].values
X_forecast = HH_forecasting.drop("HH_daily", axis=1)
X_forecast = X_forecast.drop("Date", axis=1)
y_forecast = HH_forecasting["HH_daily"].values

# %% [markdown]
# # WTI

# %%
WTI.dropna(inplace=True)
WTI.reset_index(drop=True,inplace=True)

# %%
num = 2

lags = range(1, (1+num))
WTI = WTI.assign(**{
    '{} (t-{})'.format('WTI_daily', t): WTI["WTI_daily"].shift(t)
    for t in lags
})

# %%
for i in range(num):
    WTI.drop([i],inplace=True)

WTI.reset_index(drop=True,inplace=True)

# %%
WTI1 = WTI.loc[:int((len(WTI)-1)*0.6731817),]
WTI2 = WTI.loc[int((len(WTI)-1)*0.6731817)+1:int((len(WTI)-1)*0.7288557),]
WTI3 = WTI.loc[int((len(WTI)-1)*0.7288557)+1:int((len(WTI)-1)*0.8534707),]
WTI4 = WTI.loc[int((len(WTI)-1)*0.8534707)+1:len(WTI)-251,]

# %%
frames = [WTI2,WTI3,WTI4]
WTI_predict = pd.concat(frames)
WTI_forecasting = WTI.loc[(len(WTI)-250):len(WTI),:]

# %%
X_train = WTI_predict.drop("WTI_daily", axis=1)
X_train = X_train.drop("Date", axis=1)
y_train = WTI_predict["WTI_daily"].values
X_forecast = WTI_forecasting.drop("WTI_daily", axis=1)
X_forecast = X_forecast.drop("Date", axis=1)
y_forecast = WTI_forecasting["WTI_daily"].values

# %% [markdown]
# # Gold

# %%
gold.dropna(inplace=True)
gold.reset_index(drop=True,inplace=True)

# %%
plt.figure(figsize=(15, 8))
plt.plot(gold["Gold"])

# %%
num = 1

lags = range(1, (1+num))
gold = gold.assign(**{
    '{} (t-{})'.format('Gold', t): gold["Gold"].shift(t)
    for t in lags
})

# %%
for i in range(num):
    gold.drop([i],inplace=True)

gold.reset_index(drop=True,inplace=True)

# %%
gold1 = gold.loc[:int((len(gold)-1)*0.3824164),]
gold2 = gold.loc[int((len(gold)-1)*0.3824164)+1:int((len(gold)-1)*0.4997303),]
gold3 = gold.loc[int((len(gold)-1)*0.4997303)+1:len(gold)-251,]

# %%
frames = [gold2,gold3]
gold_predict = pd.concat(frames)
gold_forecasting = gold.loc[(len(gold)-250):len(gold),:]

# %%
X_train = gold_predict.drop("Gold", axis=1)
X_train = X_train.drop("Date", axis=1)
y_train = gold_predict["Gold"].values
X_forecast = gold_forecasting.drop("Gold", axis=1)
X_forecast = X_forecast.drop("Date", axis=1)
y_forecast = gold_forecasting["Gold"].values

# %% [markdown]
# # Copper

# %%
copper.dropna(inplace=True)
copper.reset_index(drop=True,inplace=True)

# %%
num = 2

lags = range(1, (1+num))
copper = copper.assign(**{
    '{} (t-{})'.format('Copper', t): copper["Copper"].shift(t)
    for t in lags
})

# %%
for i in range(num):
    copper.drop([i],inplace=True)

copper.reset_index(drop=True,inplace=True)

# %%
copper1 = copper.loc[:int((len(copper)-1)*0.3531537),]
copper2 = copper.loc[int((len(copper)-1)*0.3531537)+1:int((len(copper)-1)*0.4390108),]
copper3 = copper.loc[int((len(copper)-1)*0.4390108)+1:len(copper)-251,]

# %%
frames = [copper2,copper3]
copper_predict = pd.concat(frames)
copper_forecasting = copper.loc[(len(copper)-250):len(copper),:]

# %%
X_train = copper_predict.drop("Copper", axis=1)
X_train = X_train.drop("Date", axis=1)
y_train = copper_predict["Copper"].values
X_forecast = copper_forecasting.drop("Copper", axis=1)
X_forecast = X_forecast.drop("Date", axis=1)
y_forecast = copper_forecasting["Copper"].values

# %% [markdown]
# # Nickel

# %%
nickel.dropna(inplace=True)
nickel.reset_index(drop=True,inplace=True)

# %%
num = 1

lags = range(1, (1+num))
nickel = nickel.assign(**{
    '{} (t-{})'.format('Nickel', t): nickel["Nickel"].shift(t)
    for t in lags
})

# %%
for i in range(num):
    nickel.drop([i],inplace=True)

nickel.reset_index(drop=True,inplace=True)

# %%
nickel1 = nickel.loc[:int((len(nickel)-1)*0.3346603),]
nickel2 = nickel.loc[int((len(nickel)-1)*0.3346603)+1:int((len(nickel)-1)*0.3870754),]
nickel3 = nickel.loc[int((len(nickel)-1)*0.3870754)+1:len(nickel)-251,]

# %%
frames = [nickel2,nickel3]
nickel_predict = pd.concat(frames)
nickel_forecasting = nickel.loc[(len(nickel)-250):len(nickel),:]

# %%
X_train = nickel_predict.drop("Nickel", axis=1)
X_train = X_train.drop("Date", axis=1)
y_train = nickel_predict["Nickel"].values
X_forecast = nickel_forecasting.drop("Nickel", axis=1)
X_forecast = X_forecast.drop("Date", axis=1)
y_forecast = nickel_forecasting["Nickel"].values

# %% [markdown]
# # Zinc

# %%
zinc.dropna(inplace=True)
zinc.reset_index(drop=True,inplace=True)

# %%
num = 1

lags = range(1, (1+num))
zinc = zinc.assign(**{
    '{} (t-{})'.format('Zinc', t): zinc["Zinc"].shift(t)
    for t in lags
})

# %%
for i in range(num):
    zinc.drop([i],inplace=True)

zinc.reset_index(drop=True,inplace=True)

# %%
zinc1 = zinc.loc[:int((len(zinc)-1)*0.3694411),]
zinc2 = zinc.loc[int((len(zinc)-1)*0.3694411)+1:int((len(zinc)-1)*0.4212133),]
zinc3 = zinc.loc[int((len(zinc)-1)*0.4212133)+1:int((len(zinc)-1)*0.4741803),]
zinc4 = zinc.loc[int((len(zinc)-1)*0.4741803)+1:len(zinc)-251,]

# %%
frames = [zinc2,zinc3,zinc4]
zinc_predict = pd.concat(frames)
zinc_forecasting = zinc.loc[(len(zinc)-250):len(zinc),:]

# %%
X_train = zinc_predict.drop("Zinc", axis=1)
X_train = X_train.drop("Date", axis=1)
y_train = zinc_predict["Zinc"].values
X_forecast = zinc_forecasting.drop("Zinc", axis=1)
X_forecast = X_forecast.drop("Date", axis=1)
y_forecast = zinc_forecasting["Zinc"].values

# %% [markdown]
# # RandomForestRegressor

# %%
from sklearn.model_selection import GridSearchCV

#training model with k-fold cross validation
def train_model_with_cv(model, params, X_train, y_train):
    gs_clf = GridSearchCV(model, params, n_jobs=-2, cv=5)
    gs_clf = gs_clf.fit(X_train, y_train)
    model = gs_clf.best_estimator_
    
    return model

# %%
from sklearn.ensemble import RandomForestRegressor

rfr = RandomForestRegressor(random_state=42)

parameters = {'n_estimators': [250,500,750,1000], 
              'max_depth': [10,20],
              'min_samples_split': [5,10],
              'min_samples_leaf': [5,10,20]
             }

rnd_best = train_model_with_cv(rfr, parameters, X_train, y_train)
print(rnd_best)
forecast_result = rnd_best.predict(X_forecast)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=10,
#                       max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=5, min_samples_split=5,
#                       min_weight_fraction_leaf=0.0, n_estimators=1000,
#                       n_jobs=None, oob_score=False, random_state=42, verbose=0,
#                       warm_start=False)

# %% [markdown]
# # Keras

# %%
from sklearn.preprocessing import RobustScaler

scaler = RobustScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_forecast_scaled = scaler.transform(X_forecast)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, SimpleRNN, LSTM, BatchNormalization, Dropout
from tensorflow.keras.regularizers import l1, l2, l1_l2
import tensorflow.keras.backend as K
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import SGD, Adam
from tensorflow.keras.initializers import RandomNormal
import optuna
from optuna.pruners import SuccessiveHalvingPruner
from optuna.samplers import TPESampler
from optuna.integration import TFKerasPruningCallback

# %% [markdown]
# # Keras-ANN

# %%
K.clear_session()
model = Sequential()
model.add(Dense(units=1000, input_dim=5, kernel_initializer='he_normal', bias_initializer='he_normal', activation='elu', 
                kernel_regularizer=l1_l2(l1=0.01,l2=0.01), bias_regularizer=l1_l2(l1=0.01,l2=0.01)))
model.add(BatchNormalization(beta_initializer='he_normal',gamma_initializer='he_normal',moving_mean_initializer='he_normal', 
                             moving_variance_initializer='he_normal',beta_regularizer=l1_l2(l1=0.01,l2=0.01),
                             gamma_regularizer=l1_l2(l1=0.01,l2=0.01)))
model.add(Dropout(rate=0.3))
model.add(Dense(units=1, kernel_initializer='he_normal', bias_initializer='he_normal', activation='linear', 
                kernel_regularizer=l1_l2(l1=0.01,l2=0.01), bias_regularizer=l1_l2(l1=0.01,l2=0.01)))
# optimizer = SGD(lr=0.15, momentum=0.01, nesterov=True)
optimizer = Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)
model.compile(loss='mean_absolute_percentage_error', optimizer=optimizer)
early_stop = EarlyStopping(monitor='val_loss',patience=30,verbose=1,restore_best_weights=True)

with tf.device('/cpu:0'):
    model.fit(X_train_scaled,y_train,epochs=1000,batch_size=50,verbose=0,validation_split=0.3,callbacks=[early_stop])

forecast_result=model.predict(X_forecast_scaled)
# Out:
# D:\Anaconda3\lib\site-packages\tensorflow_core\python\keras\callbacks.py:1225: RuntimeWarning: invalid value encountered in less
#   if self.monitor_op(current - self.min_delta, self.best):
# Restoring model weights from the end of the best epoch.
# Epoch 00164: early stopping

# %% [markdown]
# # Keras-RNN

# %%
X_train_reshape = X_train_scaled.reshape(len(X_train_scaled),5,1)
y_train_reshape = y_train.reshape(len(y_train),1)
X_forecast_reshape = X_forecast_scaled.reshape(len(X_forecast_scaled),5,1)

K.clear_session()
model = Sequential()
model.add(SimpleRNN(units=500, input_shape=(5,1), kernel_initializer='he_normal', recurrent_initializer='he_normal', 
                    bias_initializer='he_normal', activation='elu', kernel_regularizer=l1_l2(l1=0.01,l2=0.01), 
                    recurrent_regularizer=l1_l2(l1=0.01,l2=0.01), bias_regularizer=l1_l2(l1=0.01,l2=0.01), 
                    activity_regularizer=l1_l2(l1=0.01,l2=0.01)))
model.add(BatchNormalization(beta_initializer='he_normal',gamma_initializer='he_normal',moving_mean_initializer='he_normal', 
                             moving_variance_initializer='he_normal',beta_regularizer=l1_l2(l1=0.01,l2=0.01),
                             gamma_regularizer=l1_l2(l1=0.01,l2=0.01)))
model.add(Dropout(rate=0.2))
model.add(Dense(units=1, kernel_initializer='he_normal', bias_initializer='he_normal', activation='linear', 
                kernel_regularizer=l1_l2(l1=0.01,l2=0.01), bias_regularizer=l1_l2(l1=0.01,l2=0.01)))
adam=Adam(lr=0.0013, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)
model.compile(loss='mean_absolute_percentage_error', optimizer=adam)
early_stop = EarlyStopping(monitor='val_loss', patience=30, verbose=1, restore_best_weights=True)
model.fit(X_train_reshape,y_train_reshape,epochs=1000,batch_size=50,verbose=0,validation_split=0.3,callbacks=[early_stop])
forecast_result=model.predict(X_forecast_reshape)
# model.get_weights()
# Out:
# D:\Anaconda3\lib\site-packages\tensorflow_core\python\keras\callbacks.py:1225: RuntimeWarning: invalid value encountered in less
#   if self.monitor_op(current - self.min_delta, self.best):
# Restoring model weights from the end of the best epoch.
# Epoch 00127: early stopping

# %%
def objective(trial):
    
    X_train_reshape = X_train_scaled.reshape(len(X_train_scaled),5,1)
    y_train_reshape = y_train.reshape(len(y_train),1)
    X_forecast_reshape = X_forecast_scaled.reshape(len(X_forecast_scaled),5,1)
    
    K.clear_session()
    model = Sequential()
    model.add(SimpleRNN(units=trial.suggest_int('units',10,200), input_shape=(5,1), kernel_initializer='he_normal',
                        recurrent_initializer='he_normal', bias_initializer='he_normal', activation='elu', 
                        kernel_regularizer=l1_l2(l1=0.01,l2=0.01), recurrent_regularizer=l1_l2(l1=0.01,l2=0.01), 
                        bias_regularizer=l1_l2(l1=0.01,l2=0.01), activity_regularizer=l1_l2(l1=0.01,l2=0.01)))
    model.add(BatchNormalization(beta_initializer='he_normal',gamma_initializer='he_normal',moving_mean_initializer='he_normal', 
                                 moving_variance_initializer='he_normal',beta_regularizer=l1_l2(l1=0.01,l2=0.01),
                                 gamma_regularizer=l1_l2(l1=0.01,l2=0.01)))
    model.add(Dropout(rate=trial.suggest_uniform('rate',0,0.5)))
    model.add(Dense(units=1, kernel_initializer='he_normal', bias_initializer='he_normal', activation='linear', 
                    kernel_regularizer=l1_l2(l1=0.01,l2=0.01), bias_regularizer=l1_l2(l1=0.01,l2=0.01)))
    
    adam=Adam(lr=trial.suggest_uniform('lr',0.001,0.1), beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)
    model.compile(loss='mean_absolute_percentage_error', optimizer=adam)
    
    early_stop = EarlyStopping(monitor='val_loss', patience=30, verbose=1, restore_best_weights=True)
    pruning_callback = TFKerasPruningCallback(trial, 'val_loss')
    
    model.fit(X_train_reshape,y_train_reshape,epochs=1000,batch_size=50,verbose=0,validation_split=0.3,
              callbacks=[early_stop,pruning_callback])
    forecast_result=model.predict(X_forecast_reshape)
    
    y_predict = np.zeros(250)
    
    for i in range(len(forecast_result)):
        y_predict[i] = forecast_result[i]
        
    mape1 = np.abs((y_forecast - y_predict)/(y_forecast+0.00000001))
    mape2 = 0
    
    for i in range(len(mape1)):
        mape2 += mape1[i]
        
    mape3 = 100 * (mape2 / len(mape1))
    
    return mape3

sampler = TPESampler(**TPESampler.hyperopt_parameters(), seed=42)
pruner = SuccessiveHalvingPruner(min_resource=1, reduction_factor=2, min_early_stopping_rate=1)
study = optuna.create_study(pruner=pruner, sampler=sampler)
study.optimize(objective, n_trials=100, n_jobs=1)

print(study.best_params)
# Out:
# Restoring model weights from the end of the best epoch.
# Epoch 00050: early stopping
# [I 2019-11-18 11:12:28,147] Finished trial#0 resulted in value: 4.088602009620573. Current best value is 4.088602009620573 with parameters: {'units': 112, 'rate': 0.3982714934301164, 'lr': 0.019160044196750218}.
# [I 2019-11-18 11:12:33,302] Setting status of trial#1 as TrialState.PRUNED. Trial was pruned at epoch 4.
# D:\Anaconda3\lib\site-packages\tensorflow_core\python\keras\callbacks.py:1225: RuntimeWarning: invalid value encountered in less
#   if self.monitor_op(current - self.min_delta, self.best):
# [I 2019-11-18 11:12:37,510] Setting status of trial#2 as TrialState.PRUNED. Trial was pruned at epoch 2.
# [I 2019-11-18 11:12:41,785] Setting status of trial#3 as TrialState.PRUNED. Trial was pruned at epoch 2.
# D:\Anaconda3\lib\site-packages\tensorflow_core\python\keras\callbacks.py:1225: RuntimeWarning: invalid value encountered in less
#   if self.monitor_op(current - self.min_delta, self.best):
# [I 2019-11-18 11:12:45,906] Setting status of trial#4 as TrialState.PRUNED. Trial was pruned at epoch 2.
# D:\Anaconda3\lib\site-packages\tensorflow_core\python\keras\callbacks.py:1225: RuntimeWarning: invalid value encountered in less
#   if self.monitor_op(current - self.min_delta, self.best):
# [I 2019-11-18 11:12:50,038] Setting status of trial#5 as TrialState.PRUNED. Trial was pruned at epoch 2.
# D:\Anaconda3\lib\site-packages\tensorflow_core\python\keras\callbacks.py:1225: RuntimeWarning: invalid value encountered in less
#   if self.monitor_op(current - self.min_delta, self.best):
# [I 2019-11-18 11:12:54,227] Setting status of trial#6 as TrialState.PRUNED. Trial was pruned at epoch 2.
# D:\Anaconda3\lib\site-packages\tensorflow_core\python\keras\callbacks.py:1225: RuntimeWarning: invalid value encountered in less
#   if self.monitor_op(current - self.min_delta, self.best):
# [I 2019-11-18 11:12:58,397] Setting status of trial#7 as TrialState.PRUNED. Trial was pruned at epoch 2.
# D:\Anaconda3\lib\site-packages\tensorflow_core\python\keras\callbacks.py:1225: RuntimeWarning: invalid value encountered in less
#   if self.monitor_op(current - self.min_delta, self.best):
# [I 2019-11-18 11:13:02,554] Setting status of trial#8 as TrialState.PRUNED. Trial was pruned at epoch 2.
# D:\Anaconda3\lib\site-packages\tensorflow_core\python\keras\callbacks.py:1225: RuntimeWarning: invalid value encountered in less
#   if self.monitor_op(current - self.min_delta, self.best):
# [I 2019-11-18 11:13:06,682] Setting status of trial#9 as TrialState.PRUNED. Trial was pruned at epoch 2.
# D:\Anaconda3\lib\site-packages\tensorflow_core\python\keras\callbacks.py:1225: RuntimeWarning: invalid value encountered in less
#   if self.monitor_op(current - self.min_delta, self.best):
# [I 2019-11-18 11:13:10,861] Setting status of trial#10 as TrialState.PRUNED. Trial was pruned at epoch 2.
# D:\Anaconda3\lib\site-packages\tensorflow_core\python\keras\callbacks.py:1225: RuntimeWarning: invalid value encountered in less
#   if self.monitor_op(current - self.min_delta, self.best):
# [I 2019-11-18 11:13:15,047] Setting status of trial#11 as TrialState.PRUNED. Trial was pruned at epoch 2.
# D:\Anaconda3\lib\site-packages\tensorflow_core\python\keras\callbacks.py:1225: RuntimeWarning: invalid value encountered in less
#   if self.monitor_op(current - self.min_delta, self.best):
# [I 2019-11-18 11:13:19,251] Setting status of trial#12 as TrialState.PRUNED. Trial was pruned at epoch 2.
# D:\Anaconda3\lib\site-packages\tensorflow_core\python\keras\callbacks.py:1225: RuntimeWarning: invalid value encountered in less
#   if self.monitor_op(current - self.min_delta, self.best):
# [I 2019-11-18 11:13:24,500] Setting status of trial#13 as TrialState.PRUNED. Trial was pruned at epoch 4.
# [I 2019-11-18 11:13:45,187] Setting status of trial#14 as TrialState.PRUNED. Trial was pruned at epoch 32.
# D:\Anaconda3\lib\site-packages\tensorflow_core\python\keras\callbacks.py:1225: RuntimeWarning: invalid value encountered in less
#   if self.monitor_op(current - self.min_delta, self.best):
# [I 2019-11-18 11:13:49,382] Setting status of trial#15 as TrialState.PRUNED. Trial was pruned at epoch 2.
# D:\Anaconda3\lib\site-packages\tensorflow_core\python\keras\callbacks.py:1225: RuntimeWarning: invalid value encountered in less
#   if self.monitor_op(current - self.min_delta, self.best):
# [I 2019-11-18 11:13:53,578] Setting status of trial#16 as TrialState.PRUNED. Trial was pruned at epoch 2.
# D:\Anaconda3\lib\site-packages\tensorflow_core\python\keras\callbacks.py:1225: RuntimeWarning: invalid value encountered in less
#   if self.monitor_op(current - self.min_delta, self.best):
# [I 2019-11-18 11:13:57,713] Setting status of trial#17 as TrialState.PRUNED. Trial was pruned at epoch 2.
# D:\Anaconda3\lib\site-packages\tensorflow_core\python\keras\callbacks.py:1225: RuntimeWarning: invalid value encountered in less
#   if self.monitor_op(current - self.min_delta, self.best):
# [I 2019-11-18 11:14:01,882] Setting status of trial#18 as TrialState.PRUNED. Trial was pruned at epoch 2.
# D:\Anaconda3\lib\site-packages\tensorflow_core\python\keras\callbacks.py:1225: RuntimeWarning: invalid value encountered in less
#   if self.monitor_op(current - self.min_delta, self.best):
# [I 2019-11-18 11:14:06,105] Setting status of trial#19 as TrialState.PRUNED. Trial was pruned at epoch 2.
# D:\Anaconda3\lib\site-packages\tensorflow_core\python\keras\callbacks.py:1225: RuntimeWarning: invalid value encountered in less
#   if self.monitor_op(current - self.min_delta, self.best):
# [I 2019-11-18 11:14:11,328] Setting status of trial#20 as TrialState.PRUNED. Trial was pruned at epoch 4.
# Restoring model weights from the end of the best epoch.
# Epoch 00071: early stopping
# [I 2019-11-18 11:14:52,952] Finished trial#21 resulted in value: 4.142834391763747. Current best value is 4.088602009620573 with parameters: {'units': 112, 'rate': 0.3982714934301164, 'lr': 0.019160044196750218}.
# D:\Anaconda3\lib\site-packages\tensorflow_core\python\keras\callbacks.py:1225: RuntimeWarning: invalid value encountered in less
#   if self.monitor_op(current - self.min_delta, self.best):
# [I 2019-11-18 11:14:57,022] Setting status of trial#22 as TrialState.PRUNED. Trial was pruned at epoch 2.
# [I 2019-11-18 11:15:08,870] Setting status of trial#23 as TrialState.PRUNED. Trial was pruned at epoch 16.
# D:\Anaconda3\lib\site-packages\tensorflow_core\python\keras\callbacks.py:1225: RuntimeWarning: invalid value encountered in less
#   if self.monitor_op(current - self.min_delta, self.best):
# [I 2019-11-18 11:15:13,017] Setting status of trial#24 as TrialState.PRUNED. Trial was pruned at epoch 2.
# [I 2019-11-18 11:15:17,177] Setting status of trial#25 as TrialState.PRUNED. Trial was pruned at epoch 2.
# [I 2019-11-18 11:15:21,356] Setting status of trial#26 as TrialState.PRUNED. Trial was pruned at epoch 2.
# D:\Anaconda3\lib\site-packages\tensorflow_core\python\keras\callbacks.py:1225: RuntimeWarning: invalid value encountered in less
#   if self.monitor_op(current - self.min_delta, self.best):
# [I 2019-11-18 11:15:26,634] Setting status of trial#27 as TrialState.PRUNED. Trial was pruned at epoch 4.
# [I 2019-11-18 11:15:30,797] Setting status of trial#28 as TrialState.PRUNED. Trial was pruned at epoch 2.
# D:\Anaconda3\lib\site-packages\tensorflow_core\python\keras\callbacks.py:1225: RuntimeWarning: invalid value encountered in less
#   if self.monitor_op(current - self.min_delta, self.best):
# [I 2019-11-18 11:15:34,963] Setting status of trial#29 as TrialState.PRUNED. Trial was pruned at epoch 2.
# [I 2019-11-18 11:15:39,159] Setting status of trial#30 as TrialState.PRUNED. Trial was pruned at epoch 2.
# D:\Anaconda3\lib\site-packages\tensorflow_core\python\keras\callbacks.py:1225: RuntimeWarning: invalid value encountered in less
#   if self.monitor_op(current - self.min_delta, self.best):
# [I 2019-11-18 11:15:44,488] Setting status of trial#31 as TrialState.PRUNED. Trial was pruned at epoch 4.
# D:\Anaconda3\lib\site-packages\tensorflow_core\python\keras\callbacks.py:1225: RuntimeWarning: invalid value encountered in less
#   if self.monitor_op(current - self.min_delta, self.best):
# [I 2019-11-18 11:15:56,275] Setting status of trial#32 as TrialState.PRUNED. Trial was pruned at epoch 16.
# D:\Anaconda3\lib\site-packages\tensorflow_core\python\keras\callbacks.py:1225: RuntimeWarning: invalid value encountered in less
#   if self.monitor_op(current - self.min_delta, self.best):
# [I 2019-11-18 11:16:01,665] Setting status of trial#33 as TrialState.PRUNED. Trial was pruned at epoch 4.
# D:\Anaconda3\lib\site-packages\tensorflow_core\python\keras\callbacks.py:1225: RuntimeWarning: invalid value encountered in less
#   if self.monitor_op(current - self.min_delta, self.best):
# [I 2019-11-18 11:16:07,010] Setting status of trial#34 as TrialState.PRUNED. Trial was pruned at epoch 4.
# D:\Anaconda3\lib\site-packages\tensorflow_core\python\keras\callbacks.py:1225: RuntimeWarning: invalid value encountered in less
#   if self.monitor_op(current - self.min_delta, self.best):
# [I 2019-11-18 11:16:11,345] Setting status of trial#35 as TrialState.PRUNED. Trial was pruned at epoch 2.
# [I 2019-11-18 11:16:15,664] Setting status of trial#36 as TrialState.PRUNED. Trial was pruned at epoch 2.
# D:\Anaconda3\lib\site-packages\tensorflow_core\python\keras\callbacks.py:1225: RuntimeWarning: invalid value encountered in less
#   if self.monitor_op(current - self.min_delta, self.best):
# [I 2019-11-18 11:16:19,915] Setting status of trial#37 as TrialState.PRUNED. Trial was pruned at epoch 2.
# D:\Anaconda3\lib\site-packages\tensorflow_core\python\keras\callbacks.py:1225: RuntimeWarning: invalid value encountered in less
#   if self.monitor_op(current - self.min_delta, self.best):
# [I 2019-11-18 11:16:24,289] Setting status of trial#38 as TrialState.PRUNED. Trial was pruned at epoch 2.
# [I 2019-11-18 11:16:29,840] Setting status of trial#39 as TrialState.PRUNED. Trial was pruned at epoch 4.
# D:\Anaconda3\lib\site-packages\tensorflow_core\python\keras\callbacks.py:1225: RuntimeWarning: invalid value encountered in less
#   if self.monitor_op(current - self.min_delta, self.best):
# [I 2019-11-18 11:16:34,196] Setting status of trial#40 as TrialState.PRUNED. Trial was pruned at epoch 2.
# D:\Anaconda3\lib\site-packages\tensorflow_core\python\keras\callbacks.py:1225: RuntimeWarning: invalid value encountered in less
#   if self.monitor_op(current - self.min_delta, self.best):
# [I 2019-11-18 11:16:38,891] Setting status of trial#41 as TrialState.PRUNED. Trial was pruned at epoch 2.
# [I 2019-11-18 11:16:44,639] Setting status of trial#42 as TrialState.PRUNED. Trial was pruned at epoch 4.
# [I 2019-11-18 11:16:48,870] Setting status of trial#43 as TrialState.PRUNED. Trial was pruned at epoch 2.
# D:\Anaconda3\lib\site-packages\tensorflow_core\python\keras\callbacks.py:1225: RuntimeWarning: invalid value encountered in less
#   if self.monitor_op(current - self.min_delta, self.best):
# [I 2019-11-18 11:16:53,129] Setting status of trial#44 as TrialState.PRUNED. Trial was pruned at epoch 2.
# D:\Anaconda3\lib\site-packages\tensorflow_core\python\keras\callbacks.py:1225: RuntimeWarning: invalid value encountered in less
#   if self.monitor_op(current - self.min_delta, self.best):
# [I 2019-11-18 11:16:57,496] Setting status of trial#45 as TrialState.PRUNED. Trial was pruned at epoch 2.
# D:\Anaconda3\lib\site-packages\tensorflow_core\python\keras\callbacks.py:1225: RuntimeWarning: invalid value encountered in less
#   if self.monitor_op(current - self.min_delta, self.best):
# [I 2019-11-18 11:17:05,214] Setting status of trial#46 as TrialState.PRUNED. Trial was pruned at epoch 8.
# [I 2019-11-18 11:17:09,541] Setting status of trial#47 as TrialState.PRUNED. Trial was pruned at epoch 2.
# [I 2019-11-18 11:17:17,241] Setting status of trial#48 as TrialState.PRUNED. Trial was pruned at epoch 8.
# D:\Anaconda3\lib\site-packages\tensorflow_core\python\keras\callbacks.py:1225: RuntimeWarning: invalid value encountered in less
#   if self.monitor_op(current - self.min_delta, self.best):
# [I 2019-11-18 11:17:21,429] Setting status of trial#49 as TrialState.PRUNED. Trial was pruned at epoch 2.
# [I 2019-11-18 11:17:25,619] Setting status of trial#50 as TrialState.PRUNED. Trial was pruned at epoch 2.
# D:\Anaconda3\lib\site-packages\tensorflow_core\python\keras\callbacks.py:1225: RuntimeWarning: invalid value encountered in less
#   if self.monitor_op(current - self.min_delta, self.best):
# [I 2019-11-18 11:17:30,998] Setting status of trial#51 as TrialState.PRUNED. Trial was pruned at epoch 4.
# D:\Anaconda3\lib\site-packages\tensorflow_core\python\keras\callbacks.py:1225: RuntimeWarning: invalid value encountered in less
#   if self.monitor_op(current - self.min_delta, self.best):
# [I 2019-11-18 11:17:36,460] Setting status of trial#52 as TrialState.PRUNED. Trial was pruned at epoch 4.
# [I 2019-11-18 11:17:40,887] Setting status of trial#53 as TrialState.PRUNED. Trial was pruned at epoch 2.
# [I 2019-11-18 11:17:45,163] Setting status of trial#54 as TrialState.PRUNED. Trial was pruned at epoch 2.
# D:\Anaconda3\lib\site-packages\tensorflow_core\python\keras\callbacks.py:1225: RuntimeWarning: invalid value encountered in less
#   if self.monitor_op(current - self.min_delta, self.best):
# [I 2019-11-18 11:17:50,638] Setting status of trial#55 as TrialState.PRUNED. Trial was pruned at epoch 4.
# D:\Anaconda3\lib\site-packages\tensorflow_core\python\keras\callbacks.py:1225: RuntimeWarning: invalid value encountered in less
#   if self.monitor_op(current - self.min_delta, self.best):
# [I 2019-11-18 11:17:55,016] Setting status of trial#56 as TrialState.PRUNED. Trial was pruned at epoch 2.
# D:\Anaconda3\lib\site-packages\tensorflow_core\python\keras\callbacks.py:1225: RuntimeWarning: invalid value encountered in less
#   if self.monitor_op(current - self.min_delta, self.best):
# [I 2019-11-18 11:17:59,276] Setting status of trial#57 as TrialState.PRUNED. Trial was pruned at epoch 2.
# D:\Anaconda3\lib\site-packages\tensorflow_core\python\keras\callbacks.py:1225: RuntimeWarning: invalid value encountered in less
#   if self.monitor_op(current - self.min_delta, self.best):
# [I 2019-11-18 11:18:03,477] Setting status of trial#58 as TrialState.PRUNED. Trial was pruned at epoch 2.
# [I 2019-11-18 11:18:07,710] Setting status of trial#59 as TrialState.PRUNED. Trial was pruned at epoch 2.
# [I 2019-11-18 11:18:11,973] Setting status of trial#60 as TrialState.PRUNED. Trial was pruned at epoch 2.
# D:\Anaconda3\lib\site-packages\tensorflow_core\python\keras\callbacks.py:1225: RuntimeWarning: invalid value encountered in less
#   if self.monitor_op(current - self.min_delta, self.best):
# [I 2019-11-18 11:18:17,304] Setting status of trial#61 as TrialState.PRUNED. Trial was pruned at epoch 4.
# [I 2019-11-18 11:18:21,533] Setting status of trial#62 as TrialState.PRUNED. Trial was pruned at epoch 2.
# [I 2019-11-18 11:18:25,706] Setting status of trial#63 as TrialState.PRUNED. Trial was pruned at epoch 2.
# D:\Anaconda3\lib\site-packages\tensorflow_core\python\keras\callbacks.py:1225: RuntimeWarning: invalid value encountered in less
#   if self.monitor_op(current - self.min_delta, self.best):
# [I 2019-11-18 11:18:29,916] Setting status of trial#64 as TrialState.PRUNED. Trial was pruned at epoch 2.
# D:\Anaconda3\lib\site-packages\tensorflow_core\python\keras\callbacks.py:1225: RuntimeWarning: invalid value encountered in less
#   if self.monitor_op(current - self.min_delta, self.best):
# [I 2019-11-18 11:18:41,945] Setting status of trial#65 as TrialState.PRUNED. Trial was pruned at epoch 16.
# [I 2019-11-18 11:18:54,260] Setting status of trial#66 as TrialState.PRUNED. Trial was pruned at epoch 16.
# D:\Anaconda3\lib\site-packages\tensorflow_core\python\keras\callbacks.py:1225: RuntimeWarning: invalid value encountered in less
#   if self.monitor_op(current - self.min_delta, self.best):
# [I 2019-11-18 11:19:01,778] Setting status of trial#67 as TrialState.PRUNED. Trial was pruned at epoch 8.
# [I 2019-11-18 11:19:13,818] Setting status of trial#68 as TrialState.PRUNED. Trial was pruned at epoch 16.
# [I 2019-11-18 11:19:19,364] Setting status of trial#69 as TrialState.PRUNED. Trial was pruned at epoch 4.
# D:\Anaconda3\lib\site-packages\tensorflow_core\python\keras\callbacks.py:1225: RuntimeWarning: invalid value encountered in less
#   if self.monitor_op(current - self.min_delta, self.best):
# [I 2019-11-18 11:19:23,642] Setting status of trial#70 as TrialState.PRUNED. Trial was pruned at epoch 2.
# D:\Anaconda3\lib\site-packages\tensorflow_core\python\keras\callbacks.py:1225: RuntimeWarning: invalid value encountered in less
#   if self.monitor_op(current - self.min_delta, self.best):
# [I 2019-11-18 11:20:02,049] Setting status of trial#71 as TrialState.PRUNED. Trial was pruned at epoch 64.
# [I 2019-11-18 11:20:23,244] Setting status of trial#72 as TrialState.PRUNED. Trial was pruned at epoch 32.
# [I 2019-11-18 11:20:27,561] Setting status of trial#73 as TrialState.PRUNED. Trial was pruned at epoch 2.
# [I 2019-11-18 11:20:31,792] Setting status of trial#74 as TrialState.PRUNED. Trial was pruned at epoch 2.
# [I 2019-11-18 11:20:36,076] Setting status of trial#75 as TrialState.PRUNED. Trial was pruned at epoch 2.
# D:\Anaconda3\lib\site-packages\tensorflow_core\python\keras\callbacks.py:1225: RuntimeWarning: invalid value encountered in less
#   if self.monitor_op(current - self.min_delta, self.best):
# [I 2019-11-18 11:20:43,682] Setting status of trial#76 as TrialState.PRUNED. Trial was pruned at epoch 8.
# D:\Anaconda3\lib\site-packages\tensorflow_core\python\keras\callbacks.py:1225: RuntimeWarning: invalid value encountered in less
#   if self.monitor_op(current - self.min_delta, self.best):
# [I 2019-11-18 11:20:48,179] Setting status of trial#77 as TrialState.PRUNED. Trial was pruned at epoch 2.
# [I 2019-11-18 11:20:53,917] Setting status of trial#78 as TrialState.PRUNED. Trial was pruned at epoch 4.
# D:\Anaconda3\lib\site-packages\tensorflow_core\python\keras\callbacks.py:1225: RuntimeWarning: invalid value encountered in less
#   if self.monitor_op(current - self.min_delta, self.best):
# Restoring model weights from the end of the best epoch.
# Epoch 00236: early stopping
# [I 2019-11-18 11:23:10,930] Finished trial#79 resulted in value: 2.5745780468962938. Current best value is 2.5745780468962938 with parameters: {'units': 31, 'rate': 0.17605512782427862, 'lr': 0.0011377457439414908}.
# D:\Anaconda3\lib\site-packages\tensorflow_core\python\keras\callbacks.py:1225: RuntimeWarning: invalid value encountered in less
#   if self.monitor_op(current - self.min_delta, self.best):
# [I 2019-11-18 11:23:14,962] Setting status of trial#80 as TrialState.PRUNED. Trial was pruned at epoch 2.
# D:\Anaconda3\lib\site-packages\tensorflow_core\python\keras\callbacks.py:1225: RuntimeWarning: invalid value encountered in less
#   if self.monitor_op(current - self.min_delta, self.best):
# [I 2019-11-18 11:23:20,447] Setting status of trial#81 as TrialState.PRUNED. Trial was pruned at epoch 4.
# [I 2019-11-18 11:23:28,194] Setting status of trial#82 as TrialState.PRUNED. Trial was pruned at epoch 8.
# [I 2019-11-18 11:23:35,836] Setting status of trial#83 as TrialState.PRUNED. Trial was pruned at epoch 8.
# [I 2019-11-18 11:23:40,060] Setting status of trial#84 as TrialState.PRUNED. Trial was pruned at epoch 2.
# [I 2019-11-18 11:23:45,462] Setting status of trial#85 as TrialState.PRUNED. Trial was pruned at epoch 4.
# D:\Anaconda3\lib\site-packages\tensorflow_core\python\keras\callbacks.py:1225: RuntimeWarning: invalid value encountered in less
#   if self.monitor_op(current - self.min_delta, self.best):
# [I 2019-11-18 11:23:50,851] Setting status of trial#86 as TrialState.PRUNED. Trial was pruned at epoch 4.
# D:\Anaconda3\lib\site-packages\tensorflow_core\python\keras\callbacks.py:1225: RuntimeWarning: invalid value encountered in less
#   if self.monitor_op(current - self.min_delta, self.best):
# [I 2019-11-18 11:23:55,206] Setting status of trial#87 as TrialState.PRUNED. Trial was pruned at epoch 2.
# D:\Anaconda3\lib\site-packages\tensorflow_core\python\keras\callbacks.py:1225: RuntimeWarning: invalid value encountered in less
#   if self.monitor_op(current - self.min_delta, self.best):
# [I 2019-11-18 11:24:00,161] Setting status of trial#88 as TrialState.PRUNED. Trial was pruned at epoch 2.
# D:\Anaconda3\lib\site-packages\tensorflow_core\python\keras\callbacks.py:1225: RuntimeWarning: invalid value encountered in less
#   if self.monitor_op(current - self.min_delta, self.best):
# [I 2019-11-18 11:24:05,572] Setting status of trial#89 as TrialState.PRUNED. Trial was pruned at epoch 4.
# D:\Anaconda3\lib\site-packages\tensorflow_core\python\keras\callbacks.py:1225: RuntimeWarning: invalid value encountered in less
#   if self.monitor_op(current - self.min_delta, self.best):
# [I 2019-11-18 11:24:09,750] Setting status of trial#90 as TrialState.PRUNED. Trial was pruned at epoch 2.
# D:\Anaconda3\lib\site-packages\tensorflow_core\python\keras\callbacks.py:1225: RuntimeWarning: invalid value encountered in less
#   if self.monitor_op(current - self.min_delta, self.best):
# [I 2019-11-18 11:24:15,047] Setting status of trial#91 as TrialState.PRUNED. Trial was pruned at epoch 4.
# [I 2019-11-18 11:24:20,407] Setting status of trial#92 as TrialState.PRUNED. Trial was pruned at epoch 4.
# [I 2019-11-18 11:24:24,698] Setting status of trial#93 as TrialState.PRUNED. Trial was pruned at epoch 2.
# [I 2019-11-18 11:24:36,697] Setting status of trial#94 as TrialState.PRUNED. Trial was pruned at epoch 16.
# D:\Anaconda3\lib\site-packages\tensorflow_core\python\keras\callbacks.py:1225: RuntimeWarning: invalid value encountered in less
#   if self.monitor_op(current - self.min_delta, self.best):
# [I 2019-11-18 11:24:44,271] Setting status of trial#95 as TrialState.PRUNED. Trial was pruned at epoch 8.
# [I 2019-11-18 11:24:48,539] Setting status of trial#96 as TrialState.PRUNED. Trial was pruned at epoch 2.
# D:\Anaconda3\lib\site-packages\tensorflow_core\python\keras\callbacks.py:1225: RuntimeWarning: invalid value encountered in less
#   if self.monitor_op(current - self.min_delta, self.best):
# [I 2019-11-18 11:24:52,767] Setting status of trial#97 as TrialState.PRUNED. Trial was pruned at epoch 2.
# [I 2019-11-18 11:25:31,604] Setting status of trial#98 as TrialState.PRUNED. Trial was pruned at epoch 64.
# [I 2019-11-18 11:25:36,994] Setting status of trial#99 as TrialState.PRUNED. Trial was pruned at epoch 4.
# {'units': 31, 'rate': 0.17605512782427862, 'lr': 0.0011377457439414908}

# %%
K.clear_session()
model = Sequential()
model.add(SimpleRNN(units=study.best_params['units'], input_shape=(5,1), kernel_initializer='he_normal', 
                    recurrent_initializer='he_normal', bias_initializer='he_normal', activation='elu', 
                    kernel_regularizer=l1_l2(l1=0.01,l2=0.01), recurrent_regularizer=l1_l2(l1=0.01,l2=0.01), 
                    bias_regularizer=l1_l2(l1=0.01,l2=0.01), activity_regularizer=l1_l2(l1=0.01,l2=0.01)))
model.add(BatchNormalization(beta_initializer='he_normal',gamma_initializer='he_normal',moving_mean_initializer='he_normal', 
                             moving_variance_initializer='he_normal',beta_regularizer=l1_l2(l1=0.01,l2=0.01),
                             gamma_regularizer=l1_l2(l1=0.01,l2=0.01)))
model.add(Dropout(rate=study.best_params['rate']))
model.add(Dense(units=1, kernel_initializer='he_normal', bias_initializer='he_normal', activation='linear', 
                kernel_regularizer=l1_l2(l1=0.01,l2=0.01), bias_regularizer=l1_l2(l1=0.01,l2=0.01)))
adam=Adam(lr=study.best_params['lr'], beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)
model.compile(loss='mean_absolute_percentage_error', optimizer=adam)
early_stop = EarlyStopping(monitor='val_loss', patience=30, verbose=1, restore_best_weights=True)
model.fit(X_train_reshape,y_train_reshape,epochs=1000,batch_size=50,verbose=0,validation_split=0.3,callbacks=[early_stop])
forecast_result=model.predict(X_forecast_reshape)
# Out:
# D:\Anaconda3\lib\site-packages\tensorflow_core\python\keras\callbacks.py:1225: RuntimeWarning: invalid value encountered in less
#   if self.monitor_op(current - self.min_delta, self.best):
# Restoring model weights from the end of the best epoch.
# Epoch 00198: early stopping

# %% [markdown]
# # Keras-LSTM

# %%
X_train_reshape = X_train_scaled.reshape(len(X_train_scaled),5,1)
y_train_reshape = y_train.reshape(len(y_train),1)
X_forecast_reshape = X_forecast_scaled.reshape(len(X_forecast_scaled),5,1)

K.clear_session()
model = Sequential()
model.add(LSTM(units=500, input_shape=(5,1), activation="elu", kernel_initializer="he_normal", recurrent_initializer="he_normal",
               bias_initializer="he_normal"))
model.add(BatchNormalization(beta_initializer='he_normal',gamma_initializer='he_normal',moving_mean_initializer='he_normal', 
                             moving_variance_initializer='he_normal',beta_regularizer=l1_l2(l1=0.01,l2=0.01),
                             gamma_regularizer=l1_l2(l1=0.01,l2=0.01)))
model.add(Dropout(rate=0.2))
model.add(Dense(units=1, kernel_initializer='he_normal', bias_initializer='he_normal', activation='linear', 
                kernel_regularizer=l1_l2(l1=0.01,l2=0.01), bias_regularizer=l1_l2(l1=0.01,l2=0.01)))
adam=Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)
model.compile(loss='mean_absolute_percentage_error', optimizer=adam)
early_stop = EarlyStopping(monitor='val_loss', patience=50, verbose=1, restore_best_weights=True)
model.fit(X_train_reshape,y_train_reshape,epochs=3000,batch_size=50,verbose=0,validation_split=0.3,callbacks=[early_stop])
forecast_result=model.predict(X_forecast_reshape)
# Out:
# D:\Anaconda3\lib\site-packages\tensorflow_core\python\keras\callbacks.py:1225: RuntimeWarning: invalid value encountered in less
#   if self.monitor_op(current - self.min_delta, self.best):
# Restoring model weights from the end of the best epoch.
# Epoch 00094: early stopping

# %% [markdown]
# # XGBoost

# %%
import xgboost as xgb

# %%
data_matrix = xgb.DMatrix(data=X_train, label=y_train)

# %%
from sklearn.model_selection import GridSearchCV

#training model with k-fold cross validation
def train_model_with_cv(model, params, X_train, y_train):
    gs_clf = GridSearchCV(model, params, n_jobs=-2, cv=5, verbose=1)
    gs_clf = gs_clf.fit(X_train, y_train)
    model = gs_clf.best_estimator_
    
    return model

# %%
xg_reg = xgb.XGBRegressor(objective ='reg:squarederror', random_state = 42)

parameters = {'max_depth': [3,5,10,15],
              'learning_rate': [0.1],
              'n_estimators': [300,500,750],
              'gamma': [0,0.01,0.1],
              'min_child_weight': [1,3,5,7],
              'subsample': [0.5,0.7,1],
              'colsample_bytree': [0.5,0.7,1],
              'reg_alpha': [0,0.01,0.1],
              'reg_lambda': [0,0.01,0.1]
             }

xgb_best = train_model_with_cv(xg_reg, parameters, X_train, y_train)
print(xgb_best)
forecast_result = xgb_best.predict(X_forecast)
# Out:
# Fitting 5 folds for each of 11664 candidates, totalling 58320 fits
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done  36 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=-2)]: Done 186 tasks      | elapsed:    8.3s
# [Parallel(n_jobs=-2)]: Done 436 tasks      | elapsed:   26.6s
# [Parallel(n_jobs=-2)]: Done 786 tasks      | elapsed:   49.9s
# [Parallel(n_jobs=-2)]: Done 1236 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-2)]: Done 1786 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=-2)]: Done 2436 tasks      | elapsed:  3.1min
# [Parallel(n_jobs=-2)]: Done 3186 tasks      | elapsed:  4.2min
# [Parallel(n_jobs=-2)]: Done 4036 tasks      | elapsed:  6.5min
# [Parallel(n_jobs=-2)]: Done 4986 tasks      | elapsed:  9.1min
# [Parallel(n_jobs=-2)]: Done 6036 tasks      | elapsed: 13.1min
# [Parallel(n_jobs=-2)]: Done 7186 tasks      | elapsed: 15.6min
# [Parallel(n_jobs=-2)]: Done 8436 tasks      | elapsed: 17.0min
# [Parallel(n_jobs=-2)]: Done 9786 tasks      | elapsed: 19.1min
# [Parallel(n_jobs=-2)]: Done 11236 tasks      | elapsed: 23.1min
# [Parallel(n_jobs=-2)]: Done 12786 tasks      | elapsed: 28.8min
# [Parallel(n_jobs=-2)]: Done 14436 tasks      | elapsed: 31.2min
# [Parallel(n_jobs=-2)]: Done 16186 tasks      | elapsed: 33.8min
# [Parallel(n_jobs=-2)]: Done 18036 tasks      | elapsed: 38.7min
# [Parallel(n_jobs=-2)]: Done 19986 tasks      | elapsed: 44.7min
# [Parallel(n_jobs=-2)]: Done 22036 tasks      | elapsed: 47.7min
# [Parallel(n_jobs=-2)]: Done 24186 tasks      | elapsed: 54.0min
# [Parallel(n_jobs=-2)]: Done 26436 tasks      | elapsed: 62.5min
# [Parallel(n_jobs=-2)]: Done 28786 tasks      | elapsed: 66.1min
# [Parallel(n_jobs=-2)]: Done 31236 tasks      | elapsed: 74.4min
# [Parallel(n_jobs=-2)]: Done 33786 tasks      | elapsed: 81.9min
# [Parallel(n_jobs=-2)]: Done 36436 tasks      | elapsed: 87.7min
# [Parallel(n_jobs=-2)]: Done 39186 tasks      | elapsed: 98.3min
# [Parallel(n_jobs=-2)]: Done 42036 tasks      | elapsed: 103.9min
# [Parallel(n_jobs=-2)]: Done 44986 tasks      | elapsed: 119.2min
# [Parallel(n_jobs=-2)]: Done 48036 tasks      | elapsed: 126.5min
# [Parallel(n_jobs=-2)]: Done 51186 tasks      | elapsed: 141.4min
# [Parallel(n_jobs=-2)]: Done 54436 tasks      | elapsed: 150.3min
# [Parallel(n_jobs=-2)]: Done 57786 tasks      | elapsed: 165.8min
# [Parallel(n_jobs=-2)]: Done 58320 out of 58320 | elapsed: 169.4min finished
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0.1,
#              importance_type='gain', learning_rate=0.1, max_delta_step=0,
#              max_depth=3, min_child_weight=1, missing=None, n_estimators=300,
#              n_jobs=1, nthread=None, objective='reg:squarederror',
#              random_state=42, reg_alpha=0.1, reg_lambda=0.1, scale_pos_weight=1,
#              seed=None, silent=None, subsample=1, verbosity=1)

# %% [markdown]
# # Result

# %%
plt.figure(figsize=(15, 8))
plt.plot(y_forecast)
plt.plot(forecast_result)

plt.legend(['real', 'predict'])

# %%
y_predict = np.zeros(250)
for i in range(len(forecast_result)):
    y_predict[i] = forecast_result[i]

mape1 = np.abs((y_forecast - y_predict)/(y_forecast+0.00000001))

mape2 = 0
for i in range(len(mape1)):
    mape2 += mape1[i]

mape3 = 100 * (mape2 / len(mape1))
mape3
# Out:
# 2.5608398449900536

# %%
y_forecast-y_predict
# Out:
# array([-1.49277687e-03, -5.14853954e-02, -1.69313908e-02, -6.93139076e-03,
#        -6.93139076e-03, -1.69313908e-02, -1.69313908e-02, -2.69313908e-02,
#        -2.69313908e-02, -5.69313908e-02, -8.77718830e-02,  3.43812084e-02,
#        -2.21435547e-02, -7.21435547e-02,  1.43812084e-02, -3.21435547e-02,
#        -9.21435547e-02,  6.11861420e-02, -2.14355469e-03, -4.21435547e-02,
#        -2.56187916e-02,  4.43812084e-02, -2.21435547e-02, -5.21435547e-02,
#         8.43812084e-02,  2.22811699e-03,  1.02228117e-01,  3.85146046e-02,
#         5.85072231e-02, -7.58178616e-02, -3.14853954e-02,  8.55386448e-02,
#        -1.58178616e-02, -1.58178616e-02, -2.58178616e-02,  4.18213844e-03,
#        -2.58178616e-02, -1.58178616e-02, -2.58178616e-02, -4.58178616e-02,
#         1.85072231e-02,  1.85072231e-02, -1.49277687e-03,  8.51460457e-03,
#         2.85146046e-02, -1.49277687e-03,  4.85146046e-02, -1.05817862e-01,
#        -5.44613552e-02,  5.22281170e-02,  2.30686092e-02,  4.55386448e-02,
#        -2.14927769e-02, -2.44613552e-02,  3.30686092e-02,  4.85146046e-02,
#         7.41821384e-02, -1.38613510e-02, -2.03213501e-02,  4.18213844e-03,
#         8.41821384e-02,  1.61386490e-02, -3.38613510e-02, -2.58178616e-02,
#         9.41821384e-02, -7.14717865e-03,  1.12852821e-01,  1.47587433e-01,
#        -1.08257771e-01,  6.13913822e-02,  1.15721846e-01,  1.47950172e-02,
#        -2.84823742e-01, -1.70109844e-02,  2.70211792e-02,  1.32172298e-02,
#         4.59850311e-02, -1.51035309e-03, -9.03769016e-02, -3.29788208e-02,
#         4.70211792e-02,  1.24119444e-01, -1.24371815e-02, -1.56933527e-01,
#        -5.12791157e-02,  3.70211792e-02,  5.32172298e-02,  6.41194439e-02,
#        -1.09860172e-01,  2.78720884e-01, -1.99553680e-02, -9.95536804e-03,
#        -9.95536804e-03,  1.90044632e-01,  2.64241180e-01,  1.40735245e-01,
#         2.73486137e-02,  6.17348614e-01, -2.31108856e-01,  3.28148746e-01,
#         1.02958584e-01,  1.14200783e-01, -3.61592026e-01, -3.24990463e-02,
#         2.08969593e-01, -1.75385475e-02,  1.31217346e-01, -1.59632778e-01,
#        -3.36829185e-02,  2.45628300e-01, -2.03790722e-01,  3.34708786e-02,
#         3.85976219e-02,  1.24614525e-02,  2.85976219e-02, -1.91402378e-01,
#        -3.56288681e-01, -2.53493500e-01, -1.37830210e-01, -2.75209532e-01,
#        -2.37384319e-02, -1.89204693e-02, -2.98920469e-01, -3.58366632e-01,
#         1.51768446e-01,  1.70211792e-02, -5.12978821e-01,  4.69239235e-02,
#        -8.49113560e-02,  1.16815939e-01, -8.53379250e-03,  1.55386448e-02,
#        -1.48539543e-03,  4.08514605e-01,  6.89592743e-02,  4.44148350e-02,
#         4.44148350e-02, -1.08352966e-01, -1.48237419e-02, -3.14823742e-01,
#        -3.15173817e-02, -9.15173817e-02, -4.69155312e-03, -1.07420263e-01,
#         6.55386448e-02, -2.15817862e-01, -1.22143555e-01, -1.79298334e-01,
#        -3.92534351e-02,  2.74792480e-02,  4.07465649e-02,  3.50071526e-02,
#         5.53615189e-02, -6.52041817e-02, -9.85099220e-02, -8.08371544e-03,
#        -3.49928474e-02,  6.50071526e-02, -2.15476131e-02,  2.53615189e-02,
#        -1.19047260e-02,  8.80952740e-02, -1.07771883e-01,  1.31186142e-01,
#        -2.69313908e-02,  2.73068609e-01,  1.03139138e+00, -1.24958546e+00,
#         5.19091415e-02, -3.18608618e-01, -1.60966873e-02, -1.02389708e-01,
#        -1.77718830e-02,  2.22281170e-02,  1.02228117e-01, -1.48539543e-03,
#        -5.14853954e-02,  3.06860924e-03, -7.44613552e-02,  1.22281170e-02,
#        -9.77718830e-02, -5.56187916e-02, -1.88138580e-02, -6.88138580e-02,
#        -2.15476131e-02,  1.84523869e-02, -2.88138580e-02,  1.18614197e-03,
#        -3.56187916e-02, -9.88138580e-02, -9.15476131e-02,  9.50071526e-02,
#        -4.88138580e-02,  4.58094597e-03, -3.88138580e-02, -1.90472603e-03,
#        -2.56187916e-02, -1.15618792e-01, -1.61547613e-01, -1.25207520e-02,
#         5.74792480e-02, -9.49928474e-02, -2.25207520e-02, -5.61161995e-03,
#         3.43883801e-02,  7.65569687e-03,  1.76556969e-02, -2.80837154e-02,
#         1.19162846e-02, -2.80837154e-02, -7.80837154e-02, -5.61161995e-03,
#         9.43883801e-02, -9.03855610e-02,  2.19162846e-02,  5.36151886e-03,
#        -8.50992203e-03, -2.42570019e-02, -8.46384811e-02, -1.38307953e-02,
#         7.50071526e-02,  1.45809460e-02, -2.88138580e-02, -1.91904726e-01,
#         2.76556969e-02,  2.50071526e-02, -2.15476131e-02, -2.15476131e-02,
#        -1.14638481e-01, -1.18083715e-01, -1.01358700e-01, -3.97263050e-02,
#        -8.97263050e-02,  5.48669624e-02, -6.28171730e-02, -2.48846054e-03,
#         5.48669624e-02, -5.28171730e-02, -1.12817173e-01,  8.48669624e-02,
#        -4.28171730e-02, -5.28171730e-02, -1.02817173e-01, -1.05133038e-01,
#         4.92754555e-02, -3.74263763e-03,  2.62573624e-02, -5.22298145e-02,
#         4.77701855e-02, -8.24884605e-02])

# %%
plt.figure(figsize=(15, 8))
plt.plot(y_forecast-y_predict)
